# %% [markdown]
# # Erste einfache Analysen
#
# ### Benötigte Bibliotheken importieren:

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ### Einlesen der Tabelle aus CSV:

# %%
df = pd.read_csv("Comics_frei_verfuegbar.csv")
df
# Out:
#             idn                      author  \
# 0    1393285015                  Frahm, Ole
# 1    1389922022                         NaN
# 2    1395676003                Matthes, Eva
# 3    1389924378    Jüngst, Heike Elisabeth
# 4    1393283691  Eggert, Barbara Margarethe
# ..          ...                         ...
# 248  1342824938               Marlali, Ekin
# 249  1395430632   Milesi, Mikaela Elizabeth
# 250  1346262810              Suprapto, Nadi
# 251  1318678250               Ikuta, Hikaru
# 252  137934431X            Aringer, Johanna
#
#                                                author2  \
# 0                                                  NaN
# 1                Kesper-Biermann, Sylvia; Strunk, Anna
# 2                                 Mehwald, Ann-Kathrin
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 248                                    Balcisoy, Selim
# 249  Alfredo, Riordan; Echeverria, Vanessa; Yan, Li...
# 250  Nisa’, Khoirun; Sya’roni, Imam; Adam, Alif Sya...
# 251                  Wöhler, Leslie; Aizawa, Kiyoharu
# 252                     Wallner, Lars; Berglund, Ammie
#
#                                                  title subtitle  \
# 0                BEREICHSREZENSION Adaptionen im Comic      NaN
# 1    Comics in Bildungskontexten. Entwicklungen, Di...      NaN
# 2    Comics in didaktischen Kontexten – notwendige ...      NaN
# 3        Die Quer-Comics. Die 1980er und ihre Ideale      NaN
# 4          Hannes Rall: Comics: Konzept und Gestaltung      NaN
# ..                                                 ...      ...
# 248  Automated inpainting of Tex Willer comics: ada...      NaN
# 249  From comic panels to clinical practice: data c...      NaN
# 250  Scientific mapping and production analysis of ...      NaN
# 251  Statistical characteristics of comic panel vie...      NaN
# 252  Students learning about evolution through a co...      NaN
#
#                                            responsible  \
# 0                                            Ole Frahm
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                            Barbara Margarethe Eggert
# ..                                                 ...
# 248                    by Ekin Marlali, Selim Balcisoy
# 249  by Mikaela Elizabeth Milesi, Riordan Alfredo, ...
# 250  by Nadi Suprapto, Khoirun Nisa’, Imam Sya’roni...
# 251   by Hikaru Ikuta, Leslie Wöhler, Kiyoharu Aizawa
# 252   by Johanna Aringer, Lars Wallner, Ammie Berglund
#
#                                              publisher             place  \
# 0              Philipps-Universität Marburg; Schüren  Marburg; Marburg
# 1    DIPF Leibniz Institut für Bildungsforschung u...         Frankfurt
# 2    DIPF Leibniz Institut für Bildungsforschung u...         Frankfurt
# 3    DIPF Leibniz Institut für Bildungsforschung u...         Frankfurt
# 4              Philipps-Universität Marburg; Schüren  Marburg; Marburg
# ..                                                 ...               ...
# 248                                                NaN               NaN
# 249                                                NaN               NaN
# 250                                                NaN               NaN
# 251                                                NaN               NaN
# 252                                                NaN               NaN
#
#                    pages    pub_year  \
# 0       Online-Ressource  2026; 2026
# 1       Online-Ressource        2026
# 2       Online-Ressource        2026
# 3       Online-Ressource        2026
# 4       Online-Ressource  2026; 2026
# ..                   ...         ...
# 248  1 Online-Ressource.         NaN
# 249  1 Online-Ressource.         NaN
# 250  1 Online-Ressource.         NaN
# 251  1 Online-Ressource.         NaN
# 252  1 Online-Ressource.         NaN
#
#                                                  links     ddc
# 0    https://doi.org/10.25969/mediarep/24541; https...   741.5
# 1    https://doi.org/10.25656/01:34501; https://nbn...  371.32
# 2    https://doi.org/10.25656/01:34648; https://nbn...   741.5
# 3    https://doi.org/10.25656/01:34647; https://nbn...   741.5
# 4    https://doi.org/10.25969/mediarep/24540; https...   741.5
# ..                                                 ...     ...
# 248  https://doi.org/10.1007/s00371-024-03440-0; ht...   741.5
# 249  https://doi.org/10.1186/s40561-026-00434-4; ht...   741.5
# 250  https://doi.org/10.1057/s41599-024-03513-4; ht...   741.5
# 251  https://doi.org/10.1038/s41598-023-47120-w; ht...   741.5
# 252  https://doi.org/10.1186/s12052-025-00223-6; ht...   741.5
#
# [253 rows x 12 columns]

# %% [markdown]
# ### Entfernen von Datensätzen, die in der Spalte "pub_year" keinen Eintrag haben:

# %%
df = df.dropna(subset=['pub_year'])
df

# %% [markdown]
# ### Einfache Visualisierungen

# %%
# Häufigkeiten der Jahre zählen
year_counts = df['pub_year'].value_counts().reset_index()
year_counts.columns = ['pub_year', 'count']

# Barchart erstellen
fig = px.bar(year_counts, x='pub_year', y='count', title='Häufigkeiten der Publikationsjahre')
fig.show()

# %%
# Häufigkeiten der Eintrage der Variable "author" zählen
creator_counts = df['author'].value_counts().reset_index()
creator_counts.columns = ['author', 'count']

#top_50_creators = creator_counts.head(50)

# Barchart erstellen
fig2 = px.bar(creator_counts, x='author', y='count', title='Häufigkeiten der Urheber')
fig2.show()

# %%
top_20_creators = creator_counts.head(20)

# Piechart erstellen
fig3 = px.pie(top_20_creators, names=top_20_creators['author'], values=top_20_creators['count'], title='Top 20 Urheber', height=700)
#fig3.update_traces(textposition='inside', textinfo='percent+label')
fig3.show()

# %%
# Suche im Dataframe nach einer bestimmten Person:

df.loc[df['author'] == 'Schulz, Charles M.']
